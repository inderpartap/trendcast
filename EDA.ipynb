# %% [markdown]
# # Crux:
# 1) totalSales is weakly affected by weather<br>
# 2) Among weather parameters, main factors are max temperature, min temperature
#    and precipitation.<br>
# 3) Department4 is most affected by the max temperature.
# 4) Department4 is most affected by the min temperature.
# 5) Department2 is most affected by the max precipitation.
# 6) Kelowna is an outlier as precipitation values are incorrect.
# 7) Precipitation and totalSales have inverse relationship.
# 8) totalSales and totalQuantity have linear relationship.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('trendcast_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 province          city        date  totalQuantity    totalSales  \
# 0           0       AB  medicine hat  2014-01-01            5.0   2175.080796
# 1           1       AB  medicine hat  2014-01-02           57.0  13543.752146
# 2           2       AB  medicine hat  2014-01-03           23.0   4489.217330
# 3           3       AB  medicine hat  2014-01-04           62.0  12135.622549
# 4           4       AB  medicine hat  2014-01-05           26.0   5596.059495
#
#    department1  department2  department3  department4  ...  department12  \
# 0          0.0          0.0          2.0          1.0  ...           0.0
# 1          6.0         31.0         10.0          3.0  ...           4.0
# 2          0.0         10.0          0.0          0.0  ...           8.0
# 3          7.0         33.0          7.0          7.0  ...           5.0
# 4          3.0         12.0          4.0          1.0  ...           3.0
#
#    department13  department14  temperature_min  temperature_max  \
# 0           0.0           0.0            -16.6             -3.0
# 1           0.0           0.0            -18.0              5.0
# 2           0.0           0.0            -11.3              5.0
# 3           0.0           0.0            -22.0            -12.0
# 4           0.0           0.0            -31.0            -21.0
#
#    precipitation  winddirection  windspeed  peakgust  pressure
# 0            0.5          206.0        7.5     126.0    1028.3
# 1            0.5          206.0       19.3     126.0    1011.6
# 2            0.5          302.0       23.7     126.0    1006.8
# 3            0.5          287.0       18.2     126.0    1032.9
# 4            0.5          221.0       15.3     126.0    1046.4
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (51110, 27)

# %%
df=df.drop(['Unnamed: 0','department14'],axis=1)

# %%
sns.heatmap(df.corr())

# %%
#sns.pairplot(df,kind='reg')

# %%
sale=df['totalSales']/1000
sns.set(style="white", color_codes=True)
g=sns.jointplot(y=df["precipitation"]/10, x=sale, kind='kde', color="skyblue")

# %%
df.columns
# Out:
# Index(['province', 'city', 'date', 'totalQuantity', 'totalSales',
#        'department1', 'department2', 'department3', 'department4',
#        'department5', 'department6', 'department7', 'department8',
#        'department9', 'department10', 'department11', 'department12',
#        'department13', 'temperature_min', 'temperature_max', 'precipitation',
#        'winddirection', 'windspeed', 'peakgust', 'pressure'],
#       dtype='object')

# %%
df1= df[['totalSales','precipitation','windspeed','winddirection','peakgust','pressure','temperature_min','temperature_max']]

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df1.corr(),annot=True)

# %%
df.columns
# Out:
# Index(['province', 'city', 'date', 'totalQuantity', 'totalSales',
#        'department1', 'department2', 'department3', 'department4',
#        'department5', 'department6', 'department7', 'department8',
#        'department9', 'department10', 'department11', 'department12',
#        'department13', 'temperature_min', 'temperature_max', 'precipitation',
#        'winddirection', 'windspeed', 'peakgust', 'pressure'],
#       dtype='object')

# %%
impcols=df.columns[5:]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df[impcols].corr(),annot=True)

# %%
dept_weather_corr=df[impcols].corr()*100

# %%
dept_weather_corr
# Out:
#                  department1  department2  department3  department4  \
# department1       100.000000    80.326364    66.976562    35.310435
# department2        80.326364   100.000000    77.038948    46.884350
# department3        66.976562    77.038948   100.000000    49.809154
# department4        35.310435    46.884350    49.809154   100.000000
# department5        38.213128    40.417866    25.738832    -1.687836
# department6        -0.180703    -0.305484    -0.832620    -0.822695
# department7        11.133588    19.842715    18.628467    20.325887
# department8        15.428362    14.659898     8.158243     3.780760
# department9         3.805099     3.495022     2.522509     1.951140
# department10        3.372601     2.234191     0.078576    -1.527693
# department11       53.973434    58.626674    40.689286    14.178952
# department12       56.455220    62.629356    45.002655    22.744897
# department13        0.199817     1.244672     1.191743     1.119514
# temperature_min     1.090008     8.332506    21.009000    31.890214
# temperature_max     2.521808    10.849194    23.756851    36.667248
# precipitation       8.194029    12.317516     9.321866    11.027321
# winddirection      -4.552910    -4.387472    -5.518099     0.708237
# windspeed           2.291129     2.900182    -6.242829     2.023251
# peakgust            4.480664     6.056489     1.544162     4.830417
# pressure            2.215314     0.328345     3.604053    -1.488806
#
#                  department5  department6  department7  department8  \
# department1        38.213128    -0.180703    11.133588    15.428362
# department2        40.417866    -0.305484    19.842715    14.659898
# department3        25.738832    -0.832620    18.628467     8.158243
# department4        -1.687836    -0.822695    20.325887     3.780760
# department5       100.000000     0.507588     0.507063    13.251014
# department6         0.507588   100.000000    -0.584937    -0.333562
# department7         0.507063    -0.584937   100.000000    -2.422704
# department8        13.251014    -0.333562    -2.422704   100.000000
# department9         6.796730    -0.128425    -2.144871     4.731603
# department10        8.347756    -0.080796    -1.349406     4.337268
# department11       36.830625     0.537241     7.031857    13.525654
# department12       33.982608     1.076834     8.809549    16.206620
# department13        1.931956    -0.056344     0.669766    -0.536618
# temperature_min   -13.543172    -1.382254    13.851464     0.128467
# temperature_max   -14.643656    -1.582341    15.343522     0.272813
# precipitation       1.900054    -0.089649     3.510822     0.816637
# winddirection      -2.662922    -0.226669    -1.358646    -1.190139
# windspeed           1.406405    -0.512804    -5.532000     2.790877
# peakgust            4.433915    -0.921534    -0.968093    -0.976968
# pressure           -1.472357    -0.618494     5.920683   -10.189431
#
#                  department9  department10  department11  department12  \
# department1         3.805099      3.372601     53.973434     56.455220
# department2         3.495022      2.234191     58.626674     62.629356
# department3         2.522509      0.078576     40.689286     45.002655
# department4         1.951140     -1.527693     14.178952     22.744897
# department5         6.796730      8.347756     36.830625     33.982608
# department6        -0.128425     -0.080796      0.537241      1.076834
# department7        -2.144871     -1.349406      7.031857      8.809549
# department8         4.731603      4.337268     13.525654     16.206620
# department9       100.000000      1.524582      3.608647      3.118154
# department10        1.524582    100.000000      4.132687      2.929414
# department11        3.608647      4.132687    100.000000     56.481139
# department12        3.118154      2.929414     56.481139    100.000000
# department13       -0.206603     -0.129981     -0.019234      0.290518
# temperature_min    -1.527312     -2.401769     -6.932545     -3.737923
# temperature_max    -1.100745     -2.670146     -7.100566     -2.978687
# precipitation       0.532896     -0.390610      9.253955      8.692600
# winddirection      -0.226409     -1.102275     -3.509097     -0.780147
# windspeed           0.517865     -0.223329      6.572530      4.668812
# peakgust           -0.439007     -0.023746      4.897585      3.053069
# pressure           -1.947405     -1.597291     -1.410931     -1.401133
#
#                  department13  temperature_min  temperature_max  \
# department1          0.199817         1.090008         2.521808
# department2          1.244672         8.332506        10.849194
# department3          1.191743        21.009000        23.756851
# department4          1.119514        31.890214        36.667248
# department5          1.931956       -13.543172       -14.643656
# department6         -0.056344        -1.382254        -1.582341
# department7          0.669766        13.851464        15.343522
# department8         -0.536618         0.128467         0.272813
# department9         -0.206603        -1.527312        -1.100745
# department10        -0.129981        -2.401769        -2.670146
# department11        -0.019234        -6.932545        -7.100566
# department12         0.290518        -3.737923        -2.978687
# department13       100.000000        -2.165231        -1.752812
# temperature_min     -2.165231       100.000000        93.350602
# temperature_max     -1.752812        93.350602       100.000000
# precipitation       -0.102923         9.947766         7.162510
# winddirection        1.192952       -10.529869        -6.274106
# windspeed            0.171871       -18.637779       -19.092810
# peakgust             0.644439        -4.750439        -2.689032
# pressure             0.329729        -3.084415        -2.932483
#
#                  precipitation  winddirection   windspeed    peakgust  \
# department1           8.194029      -4.552910    2.291129    4.480664
# department2          12.317516      -4.387472    2.900182    6.056489
# department3           9.321866      -5.518099   -6.242829    1.544162
# department4          11.027321       0.708237    2.023251    4.830417
# department5           1.900054      -2.662922    1.406405    4.433915
# department6          -0.089649      -0.226669   -0.512804   -0.921534
# department7           3.510822      -1.358646   -5.532000   -0.968093
# department8           0.816637      -1.190139    2.790877   -0.976968
# department9           0.532896      -0.226409    0.517865   -0.439007
# department10         -0.390610      -1.102275   -0.223329   -0.023746
# department11          9.253955      -3.509097    6.572530    4.897585
# department12          8.692600      -0.780147    4.668812    3.053069
# department13         -0.102923       1.192952    0.171871    0.644439
# temperature_min       9.947766     -10.529869  -18.637779   -4.750439
# temperature_max       7.162510      -6.274106  -19.092810   -2.689032
# precipitation       100.000000      -3.766995   11.965296    3.116115
# winddirection        -3.766995     100.000000   11.833518    2.033801
# windspeed            11.965296      11.833518  100.000000   15.760109
# peakgust              3.116115       2.033801   15.760109  100.000000
# pressure             -3.423546      -7.433551  -18.902990   -5.352935
#
#                    pressure
# department1        2.215314
# department2        0.328345
# department3        3.604053
# department4       -1.488806
# department5       -1.472357
# department6       -0.618494
# department7        5.920683
# department8      -10.189431
# department9       -1.947405
# department10      -1.597291
# department11      -1.410931
# department12      -1.401133
# department13       0.329729
# temperature_min   -3.084415
# temperature_max   -2.932483
# precipitation     -3.423546
# winddirection     -7.433551
# windspeed        -18.902990
# peakgust          -5.352935
# pressure         100.000000

# %% [markdown]
# # Department whose sales are affected by max temperature!

# %%
dept_affected_by_max_temp=dept_weather_corr.loc['temperature_max'][:13]

# %%
dept_affected_by_max_temp.sort_values(ascending=False)
# Out:
# department4     36.667248
# department3     23.756851
# department7     15.343522
# department2     10.849194
# department1      2.521808
# department8      0.272813
# department9     -1.100745
# department6     -1.582341
# department13    -1.752812
# department10    -2.670146
# department12    -2.978687
# department11    -7.100566
# department5    -14.643656
# Name: temperature_max, dtype: float64

# %% [markdown]
# # Department whose sales are affected by min temperature !

# %%
dept_affected_by_min_temp=dept_weather_corr.loc['temperature_min'][:13]

# %%
dept_affected_by_min_temp.sort_values(ascending=False)
# Out:
# department4     31.890214
# department3     21.009000
# department7     13.851464
# department2      8.332506
# department1      1.090008
# department8      0.128467
# department6     -1.382254
# department9     -1.527312
# department13    -2.165231
# department10    -2.401769
# department12    -3.737923
# department11    -6.932545
# department5    -13.543172
# Name: temperature_min, dtype: float64

# %% [markdown]
# # Department whose sales are affected by precipitation !

# %%
dept_affected_by_precipitation=dept_weather_corr.loc['precipitation'][:13]
dept_affected_by_precipitation.sort_values(ascending=False)
# Out:
# department2     12.317516
# department4     11.027321
# department3      9.321866
# department11     9.253955
# department12     8.692600
# department1      8.194029
# department7      3.510822
# department5      1.900054
# department8      0.816637
# department9      0.532896
# department6     -0.089649
# department13    -0.102923
# department10    -0.390610
# Name: precipitation, dtype: float64

# %% [markdown]
# # Outlier detection !

# %%
sns.scatterplot(y=df["precipitation"], x=sale,hue=df['province'])

# %%
# By cross-checking, We found that precipitation for kelowna isn't correct!

# %%
df[(df.province=='BC') & (df.precipitation>100)].head()
# Out:
#       province     city        date  totalQuantity    totalSales  department1  \
# 25852       BC  kelowna  2015-08-07           46.0   9922.422493          7.0
# 25853       BC  kelowna  2015-08-08           48.0  12183.219737          0.0
# 25854       BC  kelowna  2015-08-09           29.0   5846.567369          2.0
# 25855       BC  kelowna  2015-08-10           61.0  16141.188803          1.0
# 25856       BC  kelowna  2015-08-11           46.0  12122.339613          5.0
#
#        department2  department3  department4  department5  ...  department11  \
# 25852         31.0          1.0          5.0          0.0  ...           0.0
# 25853         24.0         11.0          9.0          0.0  ...           0.0
# 25854         18.0          4.0          4.0          0.0  ...           1.0
# 25855         27.0          9.0         17.0          0.0  ...           3.0
# 25856         19.0         10.0          9.0          0.0  ...           0.0
#
#        department12  department13  temperature_min  temperature_max  \
# 25852           1.0           0.0              7.8             29.3
# 25853           2.0           0.0             10.0             32.8
# 25854           0.0           0.0             12.0             31.7
# 25855           2.0           0.0             14.3             32.2
# 25856           3.0           0.0             14.4             33.1
#
#        precipitation  winddirection  windspeed  peakgust  pressure
# 25852          179.1          181.0        3.9     133.2    1012.5
# 25853          179.1          181.0        7.1     126.0    1008.3
# 25854          179.1          181.0        7.2     133.2    1011.7
# 25855          179.1          181.0        7.8     133.2    1012.2
# 25856          179.1          181.0        7.8     180.0    1013.2
#
# [5 rows x 25 columns]

# %% [markdown]
# # Precipitation vs Department2 sales!

# %%
sns.scatterplot(x=df["precipitation"], y=df.department2,hue=df['province'])

# %%
#Note: If precipitation is high then Sales decreased!

# %% [markdown]
# # TotalSales vs totalQuantity (Shows a linear relationship!)

# %%
sns.scatterplot(x=df["totalSales"], y=df.totalQuantity,hue=df['province'])
